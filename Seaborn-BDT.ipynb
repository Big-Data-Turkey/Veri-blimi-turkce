# %% [markdown]
# # Seaborn'a Giriş

# %% [markdown]
# __Amaç:__
# Bu dersin amacı  **SEABORN** kütüphanesini sizlere anlatmak.Python da verilerin nasl görselleştirileceğini göstermektir. Seaborn matplotlib tabanlı bir python veri görselleştirme kütüphanesidir.

# %% [markdown]
# Source: [Seaborn Docs](http://stanford.edu/~mwaskom/software/seaborn/)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  # Line Plot (Çizgi Grafiği)

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights_wide = flights.pivot("year", "month", "passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.lineplot(data=flights_wide["May"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='May'>

# %%
sns.lineplot(data=flights_wide)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data=flights, x="year", y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x="year", y="passengers", hue="month", style="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random
sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# x ekseni değerleri
x =['sun', 'mon', 'fri', 'sat', 'tue', 'wed', 'thu']
 
# y ekseni değerleri
y =[5, 6.7, 4, 6, 2, 4.9, 1.8]
 
# plotting strip plot with seaborn
ax = sns.stripplot(x, y);
 
# x-ekseni ve y eksenine etiket verme
ax.set(xlabel ='Days', ylabel ='Amount_spend')
 
# başlık verme
plt.title('My first graph');
 
# fonksiyonu çizip gösterme
plt.show()
# Out:
# C:\Users\mobiliz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(style="whitegrid")
 
# data-set yükleme
iris = sns.load_dataset('iris')

# seaborn ile çizimi
# veri kümesinin niteliklerine karar vermek
#hangi tip yapılmalı
ax = sns.stripplot(x='species', y='sepal_length', data=iris)
 
# başlık vermek
plt.title('Graph')
 
# function to show plot
plt.show()

# %% [markdown]
# # Barplot (çubuk) grafiği
#
# * barplot([x, y, hue, data, order, hue_order, …])

# %%
df = sns.load_dataset('tips')
 
# change the estimator from mean to
# standart sapma
sns.barplot(x ='sex', y ='total_bill', data = df, 
            palette ='plasma')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Countplot (Sayım grafiği)
# * countplot([x, y, hue, data, order, …])

# %%
# dataset okuma
df = sns.load_dataset('tips')
 
sns.countplot(x ='sex', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Boxplot (Kutu grafiği)
# * boxplot([x, y, hue, data, order, hue_order, …])

# %%
# dataset okuma
df = sns.load_dataset('tips')
 
sns.boxplot(x='day', y='total_bill', data=df, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violinplot (Violin grafiği)
# * violinplot([x, y, hue, data, order, …])

# %%
# dataset okuma
df = sns.load_dataset('tips')
sns.violinplot(x='day', y='total_bill', data=df,
               hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Stripplot
# * stripplot([x, y, hue, data, order, …])

# %%
# reading the dataset
df = sns.load_dataset('tips')
sns.stripplot(x='day', y='total_bill', data=df,
              jitter=True, hue='smoker', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Heatmap (Isı Grafiği)
# * Isı haritası,matrisin değerini görselleştirmek için renkleri kullanan verilerin grafiksel bir temsili olarak tanımlanır.
# * Seaborn da ki ısı haritaları seaborn.heatmap() kullanılarak çizilebilir .

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Rastgele sayı matrisi oluşturma
# from 1 to 100
data = np.random.randint(low = 1,
                         high = 100,
                         size = (10, 10))
print("The data to be plotted:\n")
print(data)
  
# plotting the heatmap
hm = sns.heatmap(data = data)
  
# displaying the plotted heatmap
plt.show()
# Out:
# The data to be plotted:
#
# [[79  6  2  1 96 46 85 25 48 60]
#  [53 21 30 43 84 45 36 10 66 47]
#  [52 87 72  8 95  1 11 41 74  1]
#  [28 24 78 44 27 91 95 27 18 71]
#  [ 1 11 99 15 20  9 54 99 46 36]
#  [74 95 96 27 18 85 32 27  8 64]
#  [30 58 74 78  4 20 71 11 60 69]
#  [11  4 77 78 17 53 70  5 85 35]
#  [49 55 66 87 61 45 29 42 18 57]
#  [72 70 71 33 10 17 10 18 49 83]]

# %%
# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))
  
# setting the parameter values
annot = True
  
# plotting the heatmap
hm = sns.heatmap(data=data,
                annot=annot)
  
# displaying the plotted heatmap
plt.show()

# %%
# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))
  
# setting the parameter values
linewidths = 2
linecolor = "yellow"
  
# plotting the heatmap
hm = sns.heatmap(data=data,
                linewidths=linewidths,
                linecolor=linecolor)
  
# displaying the plotted heatmap
plt.show()

# %% [markdown]
# # Seaborn Kdeplot

# %%
# data x and y axis for seaborn
x= np.random.randn(200)
y = np.random.randn(200)
  
# Kde for x var
sns.kdeplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(x, shade = True , color = "Green")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(x,y)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.kdeplot(x,y, shade = True)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.kdeplot(x, y, shade=True, cbar=True)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# # Dataset in Seaborn

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
df=iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df,hue="species");

# %%
sns.pairplot(df,hue="species",markers=["o","s","D"]);

# %%
sns.pairplot(df,kind="reg",hue="species");

# %%
import seaborn as sns
flights=sns.load_dataset("flights")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import seaborn as sns
flights=sns.load_dataset("flights")
df_yeni=flights
df_yeni
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df_yeni=df_yeni.pivot("month","year","passengers");

# %%
df_yeni
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df_yeni, annot=True, fmt="d");

# %%
sns.heatmap(df_yeni, annot=True, fmt="d", linewidth=.10);

# %%
sns.heatmap(df_yeni, annot=True, fmt="d", linewidth=.5, cbar=False);
